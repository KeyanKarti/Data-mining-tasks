# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes

df=pd.read_csv('web_log_data.csv')
print(df.info())
workclass_map ={'/':1, '/MSOffice/cltreq.asp?UL=1&ACT=4&BUILD=2614&STRMVER=4&CAPREQ=0':2,
 '/MSOffice/cltreq.asp?UL=1&ACT=4&BUILD=5606&STRMVER=4&CAPREQ=0':3,
 '/_vti_bin/owssvr.dll?UL=1&ACT=4&BUILD=2614&STRMVER=4&CAPREQ=0':4,
 '/_vti_bin/owssvr.dll?UL=1&ACT=4&BUILD=5606&STRMVER=4&CAPREQ=0':5,
 '/_vti_bin/shtml.exe/_vti_rpc':6, '/_vti_inf.html':7, '/acacia.html':8,
 '/carindale.html':9, '/cbd.html':10, '/cgi-bin/FormMail.pl':11, '/code/':12,
 '/code/Global/code/emailform.html':13, '/code/Global/code/isearch.html':14,
 '/code/Global/code/location.html':15, '/code/Global/code/mainframe.html':16,
 '/code/Global/code/menu.html':17, '/code/Global/code/oform.html':18,
 '/code/Global/code/services.html':19, '/code/Global/globalhome.html':20,
 '/code/Richlands':21, '/code/Richlands/':22, '/code/Richlands/code/location.html':23,
 '/code/Richlands/code/mainframe.html':24, '/code/Richlands/richlands.html':25,
 '/code/Ultra':26, '/code/Ultra/':27, '/code/Ultra/about.htm':28,
 '/code/Ultra/contact.htm':29, '/code/Ultra/graphdes.htm':30, '/code/Ultra/images':31,
 '/code/Ultra/images/':32, '/code/Ultra/index.htm':33,
 '/code/Ultra/laminating.htm':34, '/code/Ultra/offset.htm':35,
 '/code/Ultra/photocopy.htm':36, '/code/Ultra/plan.htm':37,
 '/code/Ultra/poster.htm':38, '/code/Ultra/services.htm':39,
 '/code/Ultra/stationery.htm':40, '/code/Ultra/styling.css':41,'/code/soon.html':42,
 '/code/ultra/laminating.htm':43, '/code/ultra/offset.htm':44,
 '/code/ultra/photocopy.htm':45, '/code/ultra/poster.htm':46,
 '/code/ultra/stationery.htm':47, '/direct':48, '/direct.html':49, '/eaglefarm':50,
 '/eaglefarm.html':51, '/eaglefarm/':52, '/eaglefarm/aboutus':53,
 '/eaglefarm/aboutus/':54, '/eaglefarm/contact':55,'/eaglefarm/contact/':56,
 '/eaglefarm/default.htm':57, '/eaglefarm/disclaimer/default.asp':58,
 '/eaglefarm/fileupload':59, '/eaglefarm/fileupload/':60,
 '/eaglefarm/javascript/menu.js':61, '/eaglefarm/pdf/':62,
 '/eaglefarm/pdf/Web_Price_List.pdf':63, '/eaglefarm/pricelist':64,
 '/eaglefarm/pricelist/':65, '/eaglefarm/privacy/default.asp':66,
 '/eaglefarm/specials':67, '/eaglefarm/specials/':68, '/favicon.ico':69, '/global':70,
 '/global.html':71, '/guarantee.html':72, '/index.html':73, '/more.html':74, '/purely':75,
 '/purely.html':76, '/qcc/Map.html':77, '/qcc/qccindex.html':78, '/richlands':79,
 '/richlands.html':80, '/richlands/':81, '/richlands/aboutus':82,
 '/richlands/aboutus/':83, '/richlands/choice':84, '/richlands/choice/':85,
 '/richlands/contact':86, '/richlands/contact/':87, '/richlands/default.htm':88,
 '/richlands/documents/Acad2000-create-plot-file.pdf':89, '/richlands/enquiry':90,
 '/richlands/enquiry/':91, '/richlands/enquiry/thankyou.htm':92,
 '/richlands/fileupload':93, '/richlands/fileupload/':94,
 '/richlands/fileupload/upload.htm':95, '/richlands/javascript/menu.js':96,
 '/richlands/services':97, '/richlands/services/':98, '/richlands/services/plans':99,
 '/richlands/services/plans/':100, '/richlands/services/printing':101,
 '/richlands/services/printing/':102, '/robots.txt':103, '/services.html':104,
 '/springwood.html':105, '/sunnybank.html':106, '/valley.html':107, '/vicpoint':108,
 '/vicpoint.html':109, '/victoriapoint':110, '/virginia.html':111, '/whoare.htm':112,
 '/whoare.html':113, '/wynnum.html':114}

df['request'] = df['request'].map(workclass_map)
df['request'] = df['request'].astype(int)
df['date_time'] = pd.to_datetime(df['date_time'],format='%d/%b/%Y:%H:%M:%S')
df['time']=df['date_time'].dt.strftime("%H%M%S")
print(df.info())
df.to_csv(r'C:\Users\KARTHIK\Desktop\web_log.csv')
df2 = df[['user_id', 'time']]


X = df2.as_matrix()
test=KPrototypes(n_clusters=3, init='Huang') # n_cluster is the parameter to set the number of clusters.
y=test.fit_predict(X, categorical=[1]) # Here categorical should be set with the indices of categorical variables. In this dataset, workclass is the only categorical variable. Note: Index starts with 0.  
df2['Cluster_ID'] = y

    
# how many records are in each cluster
print("Cluster membership")
print(df2['Cluster_ID'].value_counts())

import seaborn as sns
import matplotlib.pyplot as plt
# pairplot the cluster distribution.
cluster_g = sns.pairplot(df2, hue='Cluster_ID')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5866 entries, 0 to 5865
# Data columns (total 6 columns):
# ip           5866 non-null object
# date_time    5866 non-null object
# request      5866 non-null object
# step         5866 non-null int64
# session      5866 non-null int64
# user_id      5866 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 275.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5866 entries, 0 to 5865
# Data columns (total 7 columns):
# ip           5866 non-null object
# date_time    5866 non-null datetime64[ns]
# request      5866 non-null int32
# step         5866 non-null int64
# session      5866 non-null int64
# user_id      5866 non-null int64
# time         5866 non-null object
# dtypes: datetime64[ns](1), int32(1), int64(3), object(2)
# memory usage: 298.0+ KB
# None
# ...
